# %% [markdown]
# ### For the following to work, you need to be on a google cloud and be sure that intake, dask,  zarr, intake-xarray, gcsfs and aiohttp libraries are installed

# %%
from intake import open_catalog
import zarr

# %% [markdown]
# #### Altimetry data : https://catalog.pangeo.io/browse/master/ocean/altimetry/

# %%
cat = open_catalog("https://raw.githubusercontent.com/pangeo-data/pangeo-datastore/master/intake-catalogs/ocean/altimetry.yaml")
list(cat)
# Out:
# ['al',
#  'alg',
#  'c2',
#  'e1',
#  'e1g',
#  'e2',
#  'en',
#  'enn',
#  'g2',
#  'h2',
#  'j1',
#  'j1g',
#  'j1n',
#  'j2',
#  'j2g',
#  'j2n',
#  'j3',
#  's3a',
#  's3b',
#  'tp',
#  'tpn']

# %%
dssat  = cat["al"].to_dask()
dssat
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/nv/qdcmfvcd4ld1xmf80s2n9rn80000gn/T/ipykernel_17471/1314315940.py in <module>
# ----> 1 dssat  = cat["al"].to_dask()
#       2 dssat
#
# ~/opt/anaconda3/lib/python3.9/site-packages/intake_xarray/base.py in to_dask(self)
#      67     def to_dask(self):
#      68         """Return xarray object where variables are dask arrays"""
# ---> 69         return self.read_chunked()
#      70
#      71     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/intake_xarray/base.py in read_chunked(self)
#      42     def read_chunked(self):
#      43         """Return xarray object (which will have chunks)"""
# ---> 44         self._load_metadata()
#      45         return self._ds
#      46
#
# ~/opt/anaconda3/lib/python3.9/site-packages/intake/source/base.py in _load_metadata(self)
#     234         """load metadata only if needed"""
#     235         if self._schema is None:
# --> 236             self._schema = self._get_schema()
#     237             self.dtype = self._schema.dtype
#     238             self.shape = self._schema.shape
#
# ~/opt/anaconda3/lib/python3.9/site-packages/intake_xarray/base.py in _get_schema(self)
#      16
#      17         if self._ds is None:
# ---> 18             self._open_dataset()
#      19
#      20             metadata = {
#
# ~/opt/anaconda3/lib/python3.9/site-packages/intake_xarray/xzarr.py in _open_dataset(self)
#      29
#      30         self._mapper = get_mapper(self.urlpath, **self.storage_options)
# ---> 31         self._ds = xr.open_zarr(self._mapper, **self.kwargs)
#      32
#      33     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xarray/backends/zarr.py in open_zarr(store, group, synchronizer, chunks, decode_cf, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, consolidated, overwrite_encoded_chunks, chunk_store, storage_options, decode_timedelta, use_cftime, **kwargs)
#     766     }
#     767
# --> 768     ds = open_dataset(
#     769         filename_or_obj=store,
#     770         group=group,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, backend_kwargs, *args, **kwargs)
#     493
#     494     overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 495     backend_ds = backend.open_dataset(
#     496         filename_or_obj,
#     497         drop_variables=drop_variables,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xarray/backends/zarr.py in open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, stacklevel, lock)
#     822
#     823         filename_or_obj = _normalize_path(filename_or_obj)
# --> 824         store = ZarrStore.open_group(
#     825             filename_or_obj,
#     826             group=group,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xarray/backends/zarr.py in open_group(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, stacklevel)
#     382         elif consolidated:
#     383             # TODO: an option to pass the metadata_key keyword
# --> 384             zarr_group = zarr.open_consolidated(store, **open_kwargs)
#     385         else:
#     386             zarr_group = zarr.open_group(store, **open_kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/zarr/convenience.py in open_consolidated(store, metadata_key, mode, **kwargs)
#    1176
#    1177     # setup metadata store
# -> 1178     meta_store = ConsolidatedMetadataStore(store, metadata_key=metadata_key)
#    1179
#    1180     # pass through
#
# ~/opt/anaconda3/lib/python3.9/site-packages/zarr/storage.py in __init__(self, store, metadata_key)
#    2744
#    2745         # retrieve consolidated metadata
# -> 2746         meta = json_loads(store[metadata_key])
#    2747
#    2748         # check format of consolidated metadata
#
# ~/opt/anaconda3/lib/python3.9/site-packages/fsspec/mapping.py in __getitem__(self, key, default)
#     133         k = self._key_to_str(key)
#     134         try:
# --> 135             result = self.fs.cat(k)
#     136         except self.missing_exceptions:
#     137             if default is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/fsspec/asyn.py in wrapper(*args, **kwargs)
#      86     def wrapper(*args, **kwargs):
#      87         self = obj or args[0]
# ---> 88         return sync(self.loop, func, *args, **kwargs)
#      89
#      90     return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/fsspec/asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      67         raise FSTimeoutError
#      68     if isinstance(result[0], BaseException):
# ---> 69         raise result[0]
#      70     return result[0]
#      71
#
# ~/opt/anaconda3/lib/python3.9/site-packages/fsspec/asyn.py in _runner(event, coro, result, timeout)
#      23         coro = asyncio.wait_for(coro, timeout=timeout)
#      24     try:
# ---> 25         result[0] = await coro
#      26     except Exception as ex:
#      27         result[0] = ex
#
# ~/opt/anaconda3/lib/python3.9/site-packages/fsspec/asyn.py in _cat(self, path, recursive, on_error, **kwargs)
#     342             ex = next(filter(is_exception, out), False)
#     343             if ex:
# --> 344                 raise ex
#     345         if (
#     346             len(paths) > 1
#
# ~/opt/anaconda3/lib/python3.9/site-packages/gcsfs/core.py in _cat_file(self, path, start, end)
#     676         else:
#     677             head = {}
# --> 678         headers, out = await self._call("GET", u2, headers=head)
#     679         return out
#     680
#
# ~/opt/anaconda3/lib/python3.9/site-packages/gcsfs/core.py in _call(self, method, path, json_out, info_out, *args, **kwargs)
#     338         logger.debug(f"{method.upper()}: {path}, {args}, {kwargs.get('headers')}")
#     339
# --> 340         status, headers, info, contents = await self._request(
#     341             method, path, *args, **kwargs
#     342         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/decorator.py in fun(*args, **kw)
#     219             if not kwsyntax:
#     220                 args, kw = fix(args, kw, sig)
# --> 221             return await caller(func, *(extras + args), **kw)
#     222     elif isgeneratorfunction(caller):
#     223         def fun(*args, **kw):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/gcsfs/retry.py in retry_request(func, retries, *args, **kwargs)
#     109             if retry > 0:
#     110                 await asyncio.sleep(min(random.random() + 2 ** (retry - 1), 32))
# --> 111             return await func(*args, **kwargs)
#     112         except (
#     113             HttpError,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/gcsfs/core.py in _request(self, method, path, headers, json, data, *args, **kwargs)
#     330             contents = await r.read()
#     331
# --> 332             validate_response(status, contents, path)
#     333             return status, headers, info, contents
#     334
#
# ~/opt/anaconda3/lib/python3.9/site-packages/gcsfs/retry.py in validate_response(status, content, path)
#      94             raise requests.exceptions.ProxyError()
#      95         elif "invalid" in str(msg):
# ---> 96             raise ValueError("Bad Request: %s\n%s" % (path, msg))
#      97         elif error:
#      98             raise HttpError(error)
#
# ValueError: Bad Request: https://storage.googleapis.com/download/storage/v1/b/pangeo-cnes/o/alti%2Fal%2F.zmetadata?alt=media
# User project specified in the request is invalid.
